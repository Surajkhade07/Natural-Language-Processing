# %%
import re

# %%
chat1='you are a bot 1234567890,abc@xyz.com'
chat2='take it (123)-456-7890,abcX_123@xyz.com'
chat3='ok here it is phone:1234567890,gmail:abc@xyz.in'

# %%
number=re.findall(r'\d{10}|\(\d{3}\)-\d{3}-\d{4}',chat2)
number
# Out:
# ['(123)-456-7890']

# %%
email=re.findall(r'[a-zA-Z\d_]*@[a-z]*.[com|in]*',chat2)

# %%
email
# Out:
# ['abcX_123@xyz.com']

# %%
text='''Born	Elon Reeve Musk
June 28, 1971 (age 54)
Pretoria, South Africa
Citizenship	
South Africa
Canada
United States
Education	University of Pennsylvania (BA, BS)
Occupations	
CEO and product architect of Tesla
Founder, CEO, and chief engineer of SpaceX
Founder and CEO of xAI
Founder of the Boring Company and X Corp.
Co-founder of Neuralink, OpenAI, Zip2, and X.com (part of PayPal)
President of the Musk Foundation
Political party	Independent'''

# %%
pattern='Born(.*)'
name=re.findall(pattern,text)
name[0].strip()
# Out:
# 'Elon Reeve Musk'

# %%
pattern=r'age (\d+)'
age=re.findall(pattern,text)
age
# Out:
# ['54']

# %%
pattern=r'Born.*\n(.*)\('
DOB=re.findall(pattern,text)
DOB
# Out:
# ['June 28, 1971 ']

# %%
pattern=r'Born.*\n.*\n(.*)'
Birthplace=re.findall(pattern,text)
Birthplace
# Out:
# ['Pretoria, South Africa']

# %%
def get_pattern(pattern,text):
    return re.findall(pattern,text)

# %%
def get_info(text):
    pattern1=r'Born(.*)'
    pattern2=r'age (\d+)'
    pattern3=r'Born.*\n(.*)\('
    pattern4='Born.*\n.*\n(.*)'
    Name=get_pattern(pattern1,text)
    age=get_pattern(pattern2,text)
    DOB=get_pattern(pattern3,text)
    Birthplace=get_pattern(pattern,text)
    return {
        'Name':Name[0].strip(),
        'Age':age[0],
        'DOB':DOB[0],
        'Birthplace':Birthplace[0]
    }

# %%
get_info(text)
# Out:
# {'Name': 'Elon Reeve Musk',
#  'Age': '54',
#  'DOB': 'June 28, 1971 ',
#  'Birthplace': 'Pretoria, South Africa'}
